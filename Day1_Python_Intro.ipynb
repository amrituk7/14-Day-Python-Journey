# %%
print("Hello Amritpal, welcome to Day 1 of Python!")
# Out:
# Hello Amritpal, welcome to Day 1 of Python!

# %%
name = "Amritpal"
goal = "become a planner/analyst"
days = 14

print("My name is", name)
print("I am starting a", days, "day journey to", goal)
# Out:
# My name is Amritpal
# I am starting a 14 day journey to become a planner/analyst
