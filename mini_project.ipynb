# %%
# Project Duration Calculator - Day 1 Micro Project

print("Project Duration Calculator")

task1 = int(input("Enter duration of Task 1 (in days): "))
task2 = int(input("Enter duration of Task 2 (in days): "))
task3 = int(input("Enter duration of Task 3 (in days): "))

total_duration = task1 + task2 + task3

print("Total project duration:", total_duration, "days")
# Out:
# Project Duration Calculator
# Enter duration of Task 1 (in days): 1
# Enter duration of Task 2 (in days): 15
# Enter duration of Task 3 (in days): 30
# Total project duration: 46 days
